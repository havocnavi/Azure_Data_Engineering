# %% [markdown]
# ## PySpark Operations

# %%
from pyspark.sql.functions import *
from pyspark.sql.column import *
from pyspark.sql.types import *

# %%
df=spark.read.format("csv").options(header='true', inferSchema='true').load("/Volumes/workspace/default/walmart/WalMart.csv")
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## Select 2 Methods

# %%
df1=df.select('user_id','order_id','order_date','product_id','product_category','product_name')
df1.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df2.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #Sort BY
# # Scenario-1

# %%
df3=df.sort(col('order_id').desc())
df3.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # Senario -2

# %%
df4=df.sort(['order_id','user_id'],ascending=[1,0]).select('order_date','order_id','product_id')
df4.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # Limit()

# %%
df4.limit(20).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # DropDublicates()

# %%
df5=df.dropDuplicates(subset=['product_category','product_name'])
df5.diplay()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df6=df.distinct()
df6.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df7=df.dropDuplicates()
df7.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df8=df.drop_duplicates(subset=['product_category'])
df8.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # Building a Data Frame

# %%
data=[('1','Naveen'),
      ('2','Sangeetha'),
      ('3','Ashwini'),
      ('4','Suresh'),
      ('5','Push'),
      ('6','Bhavani'),
      ('7','Ankith'),
      ('8','Veer'),
      ('9','Janani')
    ]

schema='id','Fname'
df9=spark.createDataFrame(data,schema)
df9.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>Fname</th></tr></thead><tbody><tr><td>1</td><td>Naveen</td></tr><tr><td>2</td><td>Sangeetha</td></tr><tr><td>3</td><td>Ashwini</td></tr><tr><td>4</td><td>Suresh</td></tr><tr><td>5</td><td>Push</td></tr><tr><td>6</td><td>Bhavani</td></tr><tr><td>7</td><td>Ankith</td></tr><tr><td>8</td><td>Veer</td></tr><tr><td>9</td><td>Janani</td></tr></tbody></table></div>

# %%
data2=[('Chandra',1),
       ('Sangeetha',2),
       ('Ashwini',3),
       ('Suresh',4),
       ('Push',5),
       ('Bhavani',6),
       ('Ankith',7)
    ]
schema2='Fname','id'
df10=spark.createDataFrame(data2,schema2)
df10.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Fname</th><th>id</th></tr></thead><tbody><tr><td>Chandra</td><td>1</td></tr><tr><td>Sangeetha</td><td>2</td></tr><tr><td>Ashwini</td><td>3</td></tr><tr><td>Suresh</td><td>4</td></tr><tr><td>Push</td><td>5</td></tr><tr><td>Bhavani</td><td>6</td></tr><tr><td>Ankith</td><td>7</td></tr></tbody></table></div>

# %%
df100=df9.unionByName(df10)
df100.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.createOrReplaceTempView('walmart')

# %%
# %sql
create table if not exists workspace.default.PracticeADE as select * from walmart;

select * from workspace.default.PracticeADE;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select user_id,order_id from PracticeADE
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
